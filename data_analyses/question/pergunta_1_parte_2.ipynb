# %%
import pandas as pd
import seaborn as sns
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans

base_file_path = '../../data/'


df = pd.read_csv(base_file_path+'polished3_with_gdp.csv')

male = df[df["Sex"] == "M"]
female = df[df["Sex"] == "F"]

used_columns = ["Height", "BMI", "Age", "GDP"]

# %%
from sklearn.preprocessing import StandardScaler

columns_to_normalize = used_columns

scaler = StandardScaler()

male.loc[:, columns_to_normalize] = scaler.fit_transform(male[columns_to_normalize])
female.loc[:, columns_to_normalize] = scaler.fit_transform(female[columns_to_normalize])
sns.histplot(data=male, x="GDP")
# Out:
# <Axes: xlabel='GDP', ylabel='Count'>

# %%
male.head()
# Out:
#    ID                  Name Sex       Age    Height  Weight     Team  NOC  \
# 0   1             A Dijiang   M -0.311788  0.084312    80.0    China  CHN
# 1   2              A Lamusi   M -0.493359 -0.915257    60.0    China  CHN
# 2  12     Jyri Tapani Aalto   M  0.959212 -0.715343    70.0  Finland  FIN
# 5  18  Timo Antero Aaltonen   M  0.959212  0.983925   130.0  Finland  FIN
# 7  23           Fritz Aanes   M -0.674930  0.784011    89.0   Norway  NOR
#
#          Games  Year  Season       City       Sport  \
# 0  1992 Summer  1992  Summer  Barcelona  Basketball
# 1  2012 Summer  2012  Summer     London        Judo
# 2  2000 Summer  2000  Summer     Sydney   Badminton
# 5  2000 Summer  2000  Summer     Sydney   Athletics
# 7  2000 Summer  2000  Summer     Sydney   Wrestling
#
#                                             Event     Medal  Won Medal  \
# 0                     Basketball Men's Basketball  No Medal      False
# 1                    Judo Men's Extra-Lightweight  No Medal      False
# 2                         Badminton Men's Singles  No Medal      False
# 5                        Athletics Men's Shot Put  No Medal      False
# 7  Wrestling Men's Light-Heavyweight, Greco-Roman  No Medal      False
#
#         BMI       GDP
# 0  0.412115 -0.786522
# 1 -0.939024 -0.404309
# 2  0.058037  0.757981
# 5  4.435092  0.757981
# 7  0.673312  1.648913

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from scipy.stats import kurtosis

pca = PCA(n_components=1)
pca_male = pca.fit_transform(male[used_columns])
pca_female = pca.fit_transform(female[used_columns])

# Calculate kurtosis for male and female PCA results
kurt_male = kurtosis(pca_male.squeeze())
kurt_female = kurtosis(pca_female.squeeze())

# Create the plot
fig, ax = plt.subplots()
sns.kdeplot(data=pca_male.squeeze(), ax=ax, label='Male', color='blue')
sns.kdeplot(data=pca_female.squeeze(), ax=ax, label='Female', color='red')

# Add kurtosis annotations
ax.annotate(f'Kurtosis (Male): {kurt_male:.2f}', xy=(0.7, 0.8), xycoords='axes fraction', fontsize=12, color='blue')
ax.annotate(f'Kurtosis (Female): {kurt_female:.2f}', xy=(0.7, 0.75), xycoords='axes fraction', fontsize=12, color='red')

# Add legend and show plot
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Initialize a list to store results
results = []

unique_events = male['Event'].unique()
for event in unique_events:  
    male_event = male[male['Event'] == event][used_columns]

    pca_male = PCA(n_components=1).fit_transform(male_event)

    # Calculate kurtosis for both male and female PCA results
    kurt_male = kurtosis(pca_male.squeeze())

    # Append results
    results.append({
        'Event': event,
        'Kurtosis Male': kurt_male,
        'PCA': pca_male
    })

# Convert results to a DataFrame
results_df = pd.DataFrame(results)

# Sort by kurtosis (you can choose to sort by either male or female kurtosis)
sorted_results = results_df.sort_values(by='Kurtosis Male', ascending=False)

# Display sorted results
sorted_results.reset_index(drop=True, inplace=True)
print(sorted_results)
# Out:
#                                         Event  Kurtosis Male  \
# 0            Weightlifting Men's Middleweight     101.480298
# 1        Wrestling Men's Flyweight, Freestyle      37.461802
# 2     Wrestling Men's Bantamweight, Freestyle      35.733999
# 3                  Athletics Men's 100 metres      27.897755
# 4                Judo Men's Extra-Lightweight      25.574657
# ..                                        ...            ...
# 218             Trampolining Men's Individual      -1.269761
# 219  Canoeing Men's Kayak Singles, 200 metres      -1.327544
# 220        Diving Men's Synchronized Platform      -1.339172
# 221           Rugby Sevens Men's Rugby Sevens      -1.440818
# 222     Diving Men's Synchronized Springboard      -1.453645
#
#                                                    PCA
# 0    [[-0.5370842864370722], [-0.4041337809467714],...
# 1    [[-0.5862372424494211], [0.11176230236000381],...
# 2    [[0.14002460704574846], [-0.8516404813283469],...
# 3    [[-1.0455457199371738], [-0.26849798858288726]...
# 4    [[-0.6042006124143386], [-0.8169416167547341],...
# ..                                                 ...
# 218  [[-0.45969829005310725], [-1.2337961219544662]...
# 219  [[-0.650374161990477], [0.8405518557682058], [...
# 220  [[-1.2323659515196506], [1.4978135664376928], ...
# 221  [[-1.696456334855165], [-1.4514284896741543], ...
# 222  [[0.8633705101077112], [1.6219083577914368], [...
#
# [223 rows x 3 columns]

# %%
# kayak = male[male["Event"] == "Diving Men's Synchronized Springboard"]
kayak = male[male["Event"] == "Weightlifting Men's Middleweight"]

# %%
kurt_height_kayak = kurtosis(kayak['Height'].squeeze())
kurt_bmi_kayak = kurtosis(kayak['BMI'].squeeze())
kurt_gdp_kayak = kurtosis(kayak['GDP'].squeeze())
kurt_age_kayak = kurtosis(kayak['Age'].squeeze())

# Create the plot
fig, ax = plt.subplots(figsize=(12, 6))

# Plot KDE for each variable
sns.kdeplot(data=kayak['Height'].squeeze(), ax=ax, label='Height', color='blue')
sns.kdeplot(data=kayak['BMI'].squeeze(), ax=ax, label='BMI', color='green')
sns.kdeplot(data=kayak['GDP'].squeeze(), ax=ax, label='GDP', color='orange')
sns.kdeplot(data=kayak['Age'].squeeze(), ax=ax, label='Age', color='red')

# Add kurtosis annotations
ax.annotate(f'Kurtosis (Height): {kurt_height_kayak:.2f}', xy=(0.7, 0.8), xycoords='axes fraction', fontsize=12, color='blue')
ax.annotate(f'Kurtosis (BMI): {kurt_bmi_kayak:.2f}', xy=(0.7, 0.75), xycoords='axes fraction', fontsize=12, color='green')
ax.annotate(f'Kurtosis (GDP): {kurt_gdp_kayak:.2f}', xy=(0.7, 0.70), xycoords='axes fraction', fontsize=12, color='orange')
ax.annotate(f'Kurtosis (Age): {kurt_age_kayak:.2f}', xy=(0.7, 0.65), xycoords='axes fraction', fontsize=12, color='red')

# Add legend and show plot
plt.legend()
plt.title('KDE Plots with Kurtosis Annotations')
plt.xlabel('Value')
plt.ylabel('Density')
plt.tight_layout()
plt.show()

# %%
kayak.sort_values(by='GDP', ascending=True)
# Out:
#             ID                      Name Sex       Age    Height  Weight  \
# 105779   92471                    Pe Aye   M  0.414498 -1.315084    74.0
# 992        945                Mirza Adil   M -1.582788 -0.215558    73.0
# 77084    68025             Lee Jong-Seop   M  0.414498 -0.615386    75.0
# 54021    47800            Heo Chang-Beom   M -0.493359 -0.215558    75.0
# 5902      5338     Mohammad Malik Arshad   M -0.311788 -0.815300    74.5
# ...        ...                       ...  ..       ...       ...     ...
# 94969    83128                Nico Mller   M -0.674930 -1.115170    80.0
# 101408   88753         Jack Simon Oliver   M -0.856502 -1.115170    77.0
# 8792      7825  Giovanni Battista Bardis   M -0.856502 -0.215558    85.0
# 143521  125533               Chad Vaughn   M  0.414498 -0.915257    77.0
# 85087    74807         Romain Marchessou   M -0.674930 -0.415472    77.0
#
#                  Team  NOC        Games  Year  Season            City  \
# 105779        Myanmar  MMR  1964 Summer  1964  Summer           Tokyo
# 992             Sudan  SDN  1960 Summer  1960  Summer            Roma
# 77084     South Korea  KOR  1964 Summer  1964  Summer           Tokyo
# 54021     South Korea  KOR  1964 Summer  1964  Summer           Tokyo
# 5902         Pakistan  PAK  1972 Summer  1972  Summer          Munich
# ...               ...  ...          ...   ...     ...             ...
# 94969         Germany  DEU  2016 Summer  2016  Summer  Rio de Janeiro
# 101408  Great Britain  GBR  2012 Summer  2012  Summer          London
# 8792           France  FRA  2008 Summer  2008  Summer         Beijing
# 143521  United States  USA  2008 Summer  2008  Summer         Beijing
# 85087          Monaco  MCO  2008 Summer  2008  Summer         Beijing
#
#                 Sport                             Event     Medal  Won Medal  \
# 105779  Weightlifting  Weightlifting Men's Middleweight  No Medal      False
# 992     Weightlifting  Weightlifting Men's Middleweight  No Medal      False
# 77084   Weightlifting  Weightlifting Men's Middleweight  No Medal      False
# 54021   Weightlifting  Weightlifting Men's Middleweight  No Medal      False
# 5902    Weightlifting  Weightlifting Men's Middleweight  No Medal      False
# ...               ...                               ...       ...        ...
# 94969   Weightlifting  Weightlifting Men's Middleweight  No Medal      False
# 101408  Weightlifting  Weightlifting Men's Middleweight  No Medal      False
# 8792    Weightlifting  Weightlifting Men's Middleweight  No Medal      False
# 143521  Weightlifting  Weightlifting Men's Middleweight  No Medal      False
# 85087   Weightlifting  Weightlifting Men's Middleweight  No Medal      False
#
#              BMI        GDP
# 105779  1.155752  -0.815788
# 992    -0.065846  -0.810467
# 77084   0.538612  -0.808974
# 54021   0.153626  -0.808974
# 5902    0.682529  -0.807242
# ...          ...        ...
# 94969   1.668092   1.884834
# 101408  1.302667   1.907995
# 8792    1.250984   2.101547
# 143521  1.083278   2.297373
# 85087   0.567336  12.269641
#
# [276 rows x 18 columns]

# %%
# Load the dataset
df = pd.read_csv(base_file_path+'polished3_with_gdp.csv')

# Columns to normalize
columns_to_normalize = ["Height", "BMI", "Age", "GDP"]

# Standardize the data
scaler = StandardScaler()

male = df[df["Sex"] == "M"]
female = df[df["Sex"] == "F"]

male.loc[:, columns_to_normalize] = scaler.fit_transform(male[columns_to_normalize])
female.loc[:, columns_to_normalize] = scaler.fit_transform(female[columns_to_normalize])

df = pd.concat([male, female])

# %%
from scipy.stats import entropy

selected_events = df['Event'].unique()
stats = []
for event in selected_events:
    # Filter data for the current event
    df_event = df[df['Event'] == event][used_columns]

    # Apply PCA for dimensionality reduction
    pca = PCA(n_components=1)
    transformed = pca.fit_transform(df_event)

    # Calculate kurtosis and entropy for PCA-transformed data
    ent = entropy(np.histogram(transformed.squeeze(), bins=10)[0])
    stats.append((ent, event))
sorted(stats, reverse=True)
# Out:
# [(2.231344045510518, "Sailing Women's Skiff"),
#  (2.229074631344345, "Shooting Men's Free Rifle, Three Positions, 300 metres"),
#  (2.227750669477835, "Canoeing Women's Kayak Singles, 200 metres"),
#  (2.2212894474799367, "Equestrianism Men's Three-Day Event, Individual"),
#  (2.221204412860911, "Equestrianism Men's Three-Day Event, Team"),
#  (2.219563680489677, "Swimming Women's 4 x 200 metres Freestyle Relay"),
#  (2.21299646268348, "Judo Women's Heavyweight"),
#  (2.20259612041008, "Judo Women's Half-Middleweight"),
#  (2.186581748194004, 'Tennis Mixed Doubles'),
#  (2.1857409418445624, "Golf Men's Individual"),
#  (2.1845490751908416, "Cycling Women's 500 metres Time Trial"),
#  (2.1820000314393844, "Table Tennis Women's Team"),
#  (2.180302338322364, "Taekwondo Women's Welterweight"),
#  (2.1732844235073827, "Diving Men's Synchronized Springboard"),
#  (2.169847604753803, "Table Tennis Men's Team"),
#  (2.167900171808754, "Rowing Women's Lightweight Double Sculls"),
#  (2.166819944528726, "Diving Women's Synchronized Springboard"),
#  (2.16570515965764, "Diving Women's Synchronized Platform"),
#  (2.165353964371992, "Judo Women's Extra-Lightweight"),
#  (2.163226982557206, "Rowing Women's Coxed Eights"),
#  (2.15908180549353, 'Badminton Mixed Doubles'),
#  (2.1479657714749916, "Cycling Men's Keirin"),
#  (2.1440469197085115, "Swimming Men's 10 kilometres Open Water"),
#  (2.1433879312705826, "Sailing Men's One Person Heavyweight Dinghy"),
#  (2.133819089705452, "Judo Women's Lightweight"),
#  (2.133086602336627, "Athletics Women's 3,000 metres"),
#  (2.1297362058844547, "Cycling Men's Team Sprint"),
#  (2.123760474895411, "Shooting Women's Double Trap"),
#  (2.120549807134799, "Sailing Women's Three Person Keelboat"),
#  (2.118959765285269, 'Shooting Mixed Rapid-Fire Pistol, 25 metres'),
#  (2.1165627660175734, "Golf Women's Individual"),
#  (2.1165404482568686, "Trampolining Men's Individual"),
#  (2.1122317340096544, "Fencing Women's epee, Team"),
#  (2.1097082486142393, "Cycling Women's Omnium"),
#  (2.107114864954848, "Athletics Women's 10,000 metres"),
#  (2.1067718964429893, "Diving Men's Synchronized Platform"),
#  (2.10603468612859, "Rowing Women's Quadruple Sculls"),
#  (2.1059480782578213, "Fencing Women's Sabre, Team"),
#  (2.1034952553003787, "Athletics Women's 80 metres Hurdles"),
#  (2.1023500752994995, "Water Polo Women's Water Polo"),
#  (2.100766776162638, 'Shooting Mixed Running Target, 50 metres'),
#  (2.099826066581003, "Cycling Women's Keirin"),
#  (2.0965970328659203, "Canoeing Men's Kayak Singles, 200 metres"),
#  (2.0927543449606634, "Shooting Men's Running Target, 50 metres"),
#  (2.0892146244267074, "Fencing Women's Sabre, Individual"),
#  (2.085434361248695, "Canoeing Men's Canadian Singles, Slalom"),
#  (2.0823699829175415, "Wrestling Women's Middleweight, Freestyle"),
#  (2.082091464489877, "Hockey Women's Hockey"),
#  (2.081323760143356, "Canoeing Men's Canadian Doubles, Slalom"),
#  (2.0808963503957827, "Shooting Women's Trap"),
#  (2.0807037487637663, "Cycling Women's Sprint"),
#  (2.0785640541322263, "Cycling Women's BMX"),
#  (2.0770271775235676, "Baseball Men's Baseball"),
#  (2.074660148050249, "Judo Women's Half-Heavyweight"),
#  (2.0702863581427797, "Sailing Women's Two Person Dinghy"),
#  (2.068790967206095, "Trampolining Women's Individual"),
#  (2.0686056558995034, "Wrestling Men's Bantamweight, Greco-Roman"),
#  (2.066770920174989, "Badminton Women's Doubles"),
#  (2.066473868945499, "Wrestling Men's Flyweight, Greco-Roman"),
#  (2.063440138031176, "Weightlifting Women's Super-Heavyweight"),
#  (2.0630981698102504, "Cycling Men's Mountainbike, Cross-Country"),
#  (2.0629138848589896, "Cycling Women's Points Race"),
#  (2.0622875183901668, 'Sailing Mixed 5.5 metres'),
#  (2.062233962792973, "Wrestling Women's Heavyweight, Freestyle"),
#  (2.0587117140490894, "Canoeing Men's Canadian Doubles, 500 metres"),
#  (2.0576602453828934, "Canoeing Women's Kayak Singles, Slalom"),
#  (2.0559710428514957, "Canoeing Women's Kayak Singles, 500 metres"),
#  (2.0514042974104814, "Canoeing Men's Kayak Relay 4 x 500 metres"),
#  (2.0513804625001484, "Taekwondo Women's Featherweight"),
#  (2.0503995825769215, "Cycling Men's Omnium"),
#  (2.050301522504954, "Cycling Men's Madison"),
#  (2.048877357620075, "Shooting Women's Skeet"),
#  (2.048384709181895, "Weightlifting Women's Featherweight"),
#  (2.045931909221744, "Swimming Women's 4 x 100 metres Freestyle Relay"),
#  (2.043952809543037, "Athletics Women's Hammer Throw"),
#  (2.042809061868377, "Rowing Women's Coxless Pairs"),
#  (2.0417381941966877, "Swimming Women's 4 x 100 metres Medley Relay"),
#  (2.0378221540740182, "Badminton Men's Doubles"),
#  (2.035388982088338, "Shooting Women's Sporting Pistol, 25 metres"),
#  (2.034485001836431, "Shooting Men's Skeet"),
#  (2.0328531814687283, "Rowing Men's Lightweight Coxless Fours"),
#  (2.030802238884133, "Athletics Women's 1,500 metres"),
#  (2.02804676777597, "Boxing Women's Lightweight"),
#  (2.0278760421726476, "Sailing Men's Skiff"),
#  (2.027725301015499, "Weightlifting Women's Flyweight"),
#  (2.0257304911562537, "Athletics Women's Javelin Throw"),
#  (2.0235892371596598, "Rhythmic Gymnastics Women's Individual"),
#  (2.0222969568731144, 'Equestrianism Mixed Three-Day Event, Individual'),
#  (2.0213048975662486, "Athletics Women's Pole Vault"),
#  (2.018907817003761, "Badminton Men's Singles"),
#  (2.015938416055633, "Synchronized Swimming Women's Team"),
#  (2.013724351813396, "Canoeing Women's Kayak Doubles, 500 metres"),
#  (2.0136688570489096, "Rugby Sevens Women's Rugby Sevens"),
#  (2.0131821109195185, 'Equestrianism Mixed Three-Day Event, Team'),
#  (2.008989077981322, "Cycling Women's Individual Time Trial"),
#  (2.0084928199469227, 'Equestrianism Mixed Dressage, Team'),
#  (2.0083945586910263, "Table Tennis Men's Doubles"),
#  (2.0037277463549135, "Shooting Men's Free Pistol, 50 metres"),
#  (2.0000296484511506, "Table Tennis Men's Singles"),
#  (1.9999622816381861, "Shooting Men's Running Target, 10 metres"),
#  (1.99972359145357, "Canoeing Women's Kayak Fours, 500 metres"),
#  (1.9983819566757346, "Rhythmic Gymnastics Women's Group"),
#  (1.996750350476547, "Rowing Women's Double Sculls"),
#  (1.9965285650956635, "Judo Men's Open Class"),
#  (1.9960267498263358, "Beach Volleyball Women's Beach Volleyball"),
#  (1.9945724014033657, "Taekwondo Men's Flyweight"),
#  (1.9930382650507965, "Modern Pentathlon Women's Individual"),
#  (1.9900037989443229, "Sailing Men's Two Person Dinghy"),
#  (1.9894698090978418, "Canoeing Men's Canadian Singles, 500 metres"),
#  (1.989113334744471, "Canoeing Men's Kayak Doubles, 200 metres"),
#  (1.989042003892594, "Wrestling Men's Light-Flyweight, Freestyle"),
#  (1.9874006035602425, "Weightlifting Men's Middle-Heavyweight"),
#  (1.982987487214188, "Rowing Women's Coxless Fours"),
#  (1.9829513355661341, 'Sailing Mixed Two Person Keelboat'),
#  (1.982898092929397, "Athletics Men's Hammer Throw"),
#  (1.9817392006818675, "Rowing Men's Coxed Eights"),
#  (1.979121890239292, "Swimming Women's 100 metres Breaststroke"),
#  (1.9789301977823863, "Basketball Women's Basketball"),
#  (1.9786470340671882, "Wrestling Women's Flyweight, Freestyle"),
#  (1.9760453939509706, "Archery Women's Team"),
#  (1.973491805592329, 'Equestrianism Mixed Dressage, Individual'),
#  (1.9706540060895184, "Cycling Women's Individual Pursuit, 3,000 metres"),
#  (1.9695688247255085, "Wrestling Men's Light-Flyweight, Greco-Roman"),
#  (1.9675544280847028, 'Sailing Mixed Three Person Keelboat'),
#  (1.966346261712267, "Swimming Women's 200 metres Backstroke"),
#  (1.96598688133599, "Table Tennis Women's Doubles"),
#  (1.964654304908124, "Diving Women's Platform"),
#  (1.9614428890979418, "Modern Pentathlon Men's Team"),
#  (1.9614242556937014, "Shooting Women's Air Pistol, 10 metres"),
#  (1.9587048507842093, "Diving Women's Springboard"),
#  (1.956831739389158, "Cycling Women's Mountainbike, Cross-Country"),
#  (1.9556276405237343, "Wrestling Women's Lightweight, Freestyle"),
#  (1.9556027830382758, "Swimming Men's 1,500 metres Freestyle"),
#  (1.955163276095069, "Rugby Sevens Men's Rugby Sevens"),
#  (1.9548560172635925, "Handball Men's Handball"),
#  (1.9545174377914947, "Swimming Women's 50 metres Freestyle"),
#  (1.9526507979862555, "Shooting Men's Trap"),
#  (1.9525550872887105, "Swimming Men's 4 x 100 metres Medley Relay"),
#  (1.9524819856358768, "Synchronized Swimming Women's Solo"),
#  (1.9502310923744781, "Cycling Men's BMX"),
#  (1.9493177478861379, "Archery Men's Individual"),
#  (1.9473999912619322, "Shooting Men's Air Pistol, 10 metres"),
#  (1.9464814742812395, "Synchronized Swimming Women's Duet"),
#  (1.9463877707492896, 'Sailing Mixed One Person Dinghy'),
#  (1.9455031622928782, "Cycling Women's Team Pursuit"),
#  (1.9429886578045035, "Athletics Women's 4 x 400 metres Relay"),
#  (1.9414786727546267, 'Shooting Mixed Trap'),
#  (1.9410309241204229, "Weightlifting Men's Heavyweight II"),
#  (1.939685243389855, "Swimming Women's 10 kilometres Open Water"),
#  (1.9391958542195515, "Weightlifting Women's Lightweight"),
#  (1.937675342009264, "Canoeing Men's Kayak Doubles, 500 metres"),
#  (1.9376495171215355, 'Equestrianism Mixed Jumping, Team'),
#  (1.937058074563519, "Athletics Women's Pentathlon"),
#  (1.9366406730151895, "Taekwondo Men's Heavyweight"),
#  (1.9361894232717358, "Wrestling Men's Super-Heavyweight, Greco-Roman"),
#  (1.936112319909208, "Weightlifting Men's Flyweight"),
#  (1.935317589295726, "Athletics Men's Decathlon"),
#  (1.9318834703543897, "Rowing Women's Coxed Quadruple Sculls"),
#  (1.9301418238762877, "Shooting Men's Small-Bore Rifle, Prone, 50 metres"),
#  (1.9284276819189754, "Athletics Women's Triple Jump"),
#  (1.927544530676789, "Boxing Women's Middleweight"),
#  (1.9270817248410186, "Beach Volleyball Men's Beach Volleyball"),
#  (1.9263398411512522, "Shooting Men's Double Trap"),
#  (1.9256553454529413, "Tennis Women's Doubles"),
#  (1.9252041400788373, "Basketball Men's Basketball"),
#  (1.9250050276203112, "Gymnastics Women's Team All-Around"),
#  (1.9249341132325546, "Swimming Men's 4 x 200 metres Freestyle Relay"),
#  (1.9238041627188505, "Canoeing Men's Kayak Doubles, 1,000 metres"),
#  (1.9236134598071288, "Cycling Men's Points Race"),
#  (1.9236001908994969, 'Equestrianism Mixed Jumping, Individual'),
#  (1.9234727871961004, "Weightlifting Men's Featherweight"),
#  (1.9220313270928358, "Weightlifting Women's Light-Heavyweight"),
#  (1.9214440310371832, "Canoeing Men's Kayak Singles, Slalom"),
#  (1.9213274446771065, "Tennis Men's Doubles"),
#  (1.9201761181489012, "Water Polo Men's Water Polo"),
#  (1.9192820145142424, "Archery Women's Individual"),
#  (1.9186665286761069,
#   'Shooting Mixed Small-Bore Rifle, Three Positions, 50 metres'),
#  (1.9185915995942713, "Weightlifting Women's Heavyweight"),
#  (1.9185279689016121, "Athletics Women's 5,000 metres"),
#  (1.9180533224619911, "Sailing Men's Two Person Keelboat"),
#  (1.9178196924524544, "Rowing Men's Lightweight Double Sculls"),
#  (1.9174153833122103, "Rowing Men's Coxless Pairs"),
#  (1.9152977050999442, "Weightlifting Men's Lightweight"),
#  (1.915034763146371, "Swimming Men's 4 x 100 metres Freestyle Relay"),
#  (1.912982178345558, "Shooting Men's Rapid-Fire Pistol, 25 metres"),
#  (1.9126586867298572, "Wrestling Men's Light-Heavyweight, Freestyle"),
#  (1.911264189240425, "Wrestling Men's Super-Heavyweight, Freestyle"),
#  (1.905399321527525, "Diving Men's Springboard"),
#  (1.903141184262063, "Swimming Men's 100 metres Backstroke"),
#  (1.9031113541432498, "Swimming Women's 100 metres Butterfly"),
#  (1.9009477224804217, "Athletics Men's Pole Vault"),
#  (1.8995632510411964, "Cycling Women's Road Race, Individual"),
#  (1.8989747044395873, "Cycling Women's Team Sprint"),
#  (1.8964551490003647, "Cycling Men's Sprint"),
#  (1.8942438686528842, "Gymnastics Women's Horse Vault"),
#  (1.8936180839649936, "Swimming Men's 50 metres Freestyle"),
#  (1.8892430965057594, 'Shooting Mixed Free Pistol, 50 metres'),
#  (1.8891247085242522,
#   'Shooting Mixed Free Rifle, Three Positions, 300 metres'),
#  (1.8889563760486092, 'Sailing Mixed Skiff'),
#  (1.8875602966408453, "Swimming Women's 100 metres Freestyle"),
#  (1.8867551572205263, "Rowing Men's Coxless Fours"),
#  (1.8817321964218994, "Swimming Women's 200 metres Butterfly"),
#  (1.8809532956707196, "Rowing Women's Single Sculls"),
#  (1.8695900616824885, "Hockey Men's Hockey"),
#  (1.8676532674929271, "Sailing Women's One Person Dinghy"),
#  (1.865404579707827, 'Shooting Mixed Skeet'),
#  (1.8645125606825217, "Volleyball Men's Volleyball"),
#  (1.8613850429702126, "Rowing Women's Coxed Fours"),
#  (1.8606300818982116, "Athletics Men's Discus Throw"),
#  (1.8557481091746608, 'Shooting Mixed Small-Bore Rifle, Prone, 50 metres'),
#  (1.853175797522688, "Weightlifting Men's Super-Heavyweight"),
#  (1.8524762340631096, "Swimming Men's 200 metres Butterfly"),
#  (1.8516822040385406, "Canoeing Men's Canadian Singles, 200 metres"),
#  (1.8506578209906603, "Football Women's Football"),
#  (1.8489090552879877, "Judo Women's Middleweight"),
#  (1.848359743086417,
#   "Shooting Women's Small-Bore Rifle, Three Positions, 50 metres"),
#  (1.843981200371577, "Archery Men's Team"),
#  (1.8434555331736162, "Athletics Women's High Jump"),
#  (1.843194728183816, "Athletics Women's 10 kilometres Walk"),
#  (1.8419357356384232, "Sailing Men's Windsurfer"),
#  (1.8397676132300809, "Gymnastics Women's Balance Beam"),
#  (1.8397493555352666, "Gymnastics Women's Floor Exercise"),
#  (1.8394163870940126, "Athletics Women's 3,000 metres Steeplechase"),
#  (1.8393155719140866, "Cycling Men's Individual Pursuit, 4,000 metres"),
#  (1.8390420605145366, "Gymnastics Women's Uneven Bars"),
#  (1.837728939933548, "Fencing Men's Sabre, Team"),
#  (1.8359166476544988, "Gymnastics Women's Individual All-Around"),
#  (1.8343595299762572, 'Sailing Mixed Multihull'),
#  (1.8343405372753334, "Weightlifting Men's Bantamweight"),
#  (1.8311183318658428, "Athletics Men's Shot Put"),
#  (1.8297188116542151, "Cycling Men's Tandem Sprint, 2,000 metres"),
#  (1.8296912717461988, "Sailing Women's Windsurfer"),
#  (1.8281864007353241, "Volleyball Women's Volleyball"),
#  (1.8251674110547855, "Athletics Women's 400 metres"),
#  (1.8247351408894836, "Rowing Men's Coxed Pairs"),
#  (1.8223575866615684, "Fencing Women's epee, Individual"),
#  (1.8206243350680604, "Fencing Men's epee, Individual"),
#  (1.8165185453402, "Canoeing Men's Kayak Fours, 1,000 metres"),
#  (1.8159723157244836, 'Sailing Mixed Two Person Heavyweight Dinghy'),
#  (1.8146714318299857, "Athletics Women's Shot Put"),
#  (1.8132954566846267, "Triathlon Women's Olympic Distance"),
#  (1.81212748029314, "Weightlifting Men's Heavyweight"),
#  (1.8111270196443294, "Judo Men's Lightweight"),
#  (1.8063143862010997,
#   "Shooting Men's Small-Bore Rifle, Three Positions, 50 metres"),
#  (1.8025131866555608, "Swimming Men's 100 metres Butterfly"),
#  (1.7987124212739052, "Softball Women's Softball"),
#  (1.7978783602781032, "Wrestling Men's Lightweight, Freestyle"),
#  (1.79288779071972, "Swimming Men's 200 metres Backstroke"),
#  (1.7911087331546238, "Boxing Women's Flyweight"),
#  (1.790746044597979, "Wrestling Men's Heavyweight, Freestyle"),
#  (1.7896957458795122, "Fencing Men's Sabre, Individual"),
#  (1.7883132157504287, "Cycling Men's Individual Time Trial"),
#  (1.785511046812609, "Athletics Women's 400 metres Hurdles"),
#  (1.7837299635577797, "Rowing Men's Quadruple Sculls"),
#  (1.7706349716573822, "Badminton Women's Singles"),
#  (1.7704817688983814, "Boxing Men's Light-Heavyweight"),
#  (1.7675068409203474, "Athletics Women's 20 kilometres Walk"),
#  (1.7668441405080977, "Athletics Women's Marathon"),
#  (1.7667623917951267, "Taekwondo Women's Flyweight"),
#  (1.7655822702147916, 'Sailing Mixed Windsurfer'),
#  (1.7635654358837505, "Cycling Men's 1,000 metres Time Trial"),
#  (1.7616943720352236, "Swimming Men's 400 metres Freestyle"),
#  (1.7602672847424914, "Modern Pentathlon Men's Individual"),
#  (1.7596380183282492, "Judo Men's Half-Lightweight"),
#  (1.7581515485599222, "Boxing Men's Lightweight"),
#  (1.7524394430635721, "Athletics Men's 4 x 100 metres Relay"),
#  (1.7513916195901658, "Athletics Men's 10,000 metres"),
#  (1.7512208444883421, "Fencing Men's Foil, Team"),
#  (1.749735151996721, "Fencing Men's epee, Team"),
#  (1.7451257598185077, "Rowing Men's Coxed Fours"),
#  (1.7448662044796392, "Swimming Women's 200 metres Individual Medley"),
#  (1.7442011891301143, "Diving Men's Platform"),
#  (1.7325573769325708, "Cycling Men's Team Pursuit, 4,000 metres"),
#  (1.7254308232638582, "Wrestling Men's Light-Heavyweight, Greco-Roman"),
#  (1.7059505100853094, "Fencing Women's Foil, Team"),
#  (1.7046124297186631, "Handball Women's Handball"),
#  (1.7031114146116164, "Athletics Men's 3,000 metres Steeplechase"),
#  (1.7023208843287048, "Weightlifting Men's Heavyweight I"),
#  (1.7006040661108286, "Boxing Men's Super-Heavyweight"),
#  (1.6986709799899762, "Fencing Men's Foil, Individual"),
#  (1.6914671422460272, "Wrestling Men's Middleweight, Greco-Roman"),
#  (1.6867032933467976, "Athletics Men's 4 x 400 metres Relay"),
#  (1.6853394632360976, "Athletics Women's Discus Throw"),
#  (1.6832414654479662, "Wrestling Men's Middleweight, Freestyle"),
#  (1.681929940289295, "Athletics Men's 400 metres"),
#  (1.6796379445758365, "Athletics Women's Heptathlon"),
#  (1.6771218761777353, "Athletics Men's 5,000 metres"),
#  (1.6751709147517642, "Canoeing Men's Canadian Singles, 1,000 metres"),
#  (1.6716944199819035, "Athletics Women's 100 metres Hurdles"),
#  (1.67034202377875, "Weightlifting Men's Light-Heavyweight"),
#  (1.669034387236507, "Swimming Women's 200 metres Breaststroke"),
#  (1.6681849626272878, "Fencing Women's Foil, Individual"),
#  (1.6631911387619713, "Wrestling Men's Heavyweight, Greco-Roman"),
#  (1.6616245423189446, "Swimming Women's 200 metres Freestyle"),
#  (1.6539183238854573, "Taekwondo Men's Featherweight"),
#  (1.6532878686690846, "Taekwondo Men's Welterweight"),
#  (1.6497843498252514, "Swimming Men's 200 metres Individual Medley"),
#  (1.6492328963993692, "Tennis Men's Singles"),
#  (1.641498864189815, "Boxing Men's Bantamweight"),
#  (1.641381399956826, "Judo Men's Middleweight"),
#  (1.6410728933640555, "Swimming Women's 400 metres Individual Medley"),
#  (1.6345458721032136, "Rowing Men's Double Sculls"),
#  (1.6341808524712866, "Canoeing Men's Kayak Singles, 500 metres"),
#  (1.6331704014726243, "Swimming Men's 100 metres Freestyle"),
#  (1.6331514695188403, "Boxing Men's Light-Flyweight"),
#  (1.6200480195695575, "Athletics Men's 20 kilometres Walk"),
#  (1.6190041802273931, "Athletics Women's Long Jump"),
#  (1.614356187040772, "Athletics Women's 800 metres"),
#  (1.6139153769260366, "Athletics Men's 50 kilometres Walk"),
#  (1.6125479481746672, "Athletics Men's High Jump"),
#  (1.6103982420024145, "Canoeing Men's Canadian Doubles, 1,000 metres"),
#  (1.6094824894869284, "Athletics Men's 110 metres Hurdles"),
#  (1.6021605814289295, "Boxing Men's Light-Middleweight"),
#  (1.6018110906567848, "Athletics Men's Javelin Throw"),
#  (1.5982041391004436, "Table Tennis Women's Singles"),
#  (1.5960947064721265, "Judo Men's Half-Heavyweight"),
#  (1.5925497668339097, "Swimming Men's 200 metres Freestyle"),
#  (1.5903185894899188, "Athletics Women's 4 x 100 metres Relay"),
#  (1.5875214267757574, "Athletics Women's 100 metres"),
#  (1.584070648817662, "Athletics Women's 200 metres"),
#  (1.5694939002825512, "Boxing Men's Featherweight"),
#  (1.5662705452346088, "Canoeing Men's Kayak Singles, 1,000 metres"),
#  (1.5637136946634094, "Swimming Men's 100 metres Breaststroke"),
#  (1.561175472033896, "Athletics Men's 400 metres Hurdles"),
#  (1.5481252213469825, "Swimming Men's 200 metres Breaststroke"),
#  (1.543913845582268, "Taekwondo Women's Heavyweight"),
#  (1.5388310512045804, "Judo Men's Heavyweight"),
#  (1.5175253022218564, "Judo Women's Half-Lightweight"),
#  (1.5152828787743056, "Shooting Men's Air Rifle, 10 metres"),
#  (1.5133101800299105, "Sailing Men's One Person Dinghy"),
#  (1.5104825683864957, "Football Men's Football"),
#  (1.5071879388112457, "Wrestling Men's Welterweight, Freestyle"),
#  (1.5019275170714497, "Athletics Men's 1,500 metres"),
#  (1.4991480525385454, "Athletics Men's Triple Jump"),
#  (1.4991127240395006, "Swimming Women's 400 metres Freestyle"),
#  (1.4986230360249653, "Cycling Men's Road Race, Individual"),
#  (1.490343149216893, "Triathlon Men's Olympic Distance"),
#  (1.4861241287946156, "Wrestling Women's Featherweight, Freestyle"),
#  (1.485229474366605, "Athletics Men's 200 metres"),
#  (1.4769724782658404, "Boxing Men's Heavyweight"),
#  (1.4674967742796952, "Swimming Women's 800 metres Freestyle"),
#  (1.4661543302662219, "Swimming Women's 100 metres Backstroke"),
#  (1.4468185044780209, "Weightlifting Women's Middleweight"),
#  (1.4436656266518721, "Boxing Men's Flyweight"),
#  (1.419634428802051, "Judo Men's Half-Middleweight"),
#  (1.3903757529877425, "Wrestling Men's Featherweight, Greco-Roman"),
#  (1.3791236054072762, "Cycling Men's 100 kilometres Team Time Trial"),
#  (1.3753583006239138, "Gymnastics Men's Team All-Around"),
#  (1.371093929081858, "Tennis Women's Singles"),
#  (1.3568209384931873, "Athletics Men's Long Jump"),
#  (1.303092403761719, "Wrestling Women's Light-Heavyweight, Freestyle"),
#  (1.297550389873911, "Swimming Men's 400 metres Individual Medley"),
#  (1.283603358576937, "Boxing Men's Light-Welterweight"),
#  (1.2770876626163798, "Athletics Men's Marathon"),
#  (1.2719448374197815, "Gymnastics Men's Horse Vault"),
#  (1.2542006972462123, "Shooting Women's Air Rifle, 10 metres"),
#  (1.2514631517776733, "Wrestling Men's Featherweight, Freestyle"),
#  (1.248233731614302, "Boxing Men's Welterweight"),
#  (1.242153094167744, "Wrestling Men's Welterweight, Greco-Roman"),
#  (1.1677864114641572, "Wrestling Men's Lightweight, Greco-Roman"),
#  (1.1592026809978946, "Boxing Men's Middleweight"),
#  (1.0570345908439662, "Wrestling Men's Bantamweight, Freestyle"),
#  (1.005238157105604, 'Sailing Mixed Two Person Dinghy'),
#  (0.9811029196975858, "Wrestling Men's Flyweight, Freestyle"),
#  (0.9658918805684268, "Athletics Men's 800 metres"),
#  (0.8973043980439963, "Rowing Men's Single Sculls"),
#  (0.8845782608505226, "Judo Men's Extra-Lightweight"),
#  (0.8595086848161482, "Athletics Men's 100 metres"),
#  (0.8352758800647718, "Gymnastics Men's Horizontal Bar"),
#  (0.8140181139021102, "Gymnastics Men's Floor Exercise"),
#  (0.8070137003210045, "Gymnastics Men's Pommelled Horse"),
#  (0.8055142351036997, "Gymnastics Men's Parallel Bars"),
#  (0.8005427724155926, "Gymnastics Men's Rings"),
#  (0.7947772087400511, "Gymnastics Men's Individual All-Around"),
#  (0.4217337993143343, "Weightlifting Men's Middleweight")]
